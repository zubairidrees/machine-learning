# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x **2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'r-')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
## Object Oriented Method

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig,axes = plt.subplots()

axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)
plt.tight_layout()
#axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
    current_ax.plot(x,y)
    
axes[0].plot(x,y,'g')

# %%
fig = plt.figure(figsize=(3,2),dpi=100)
#fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(figsize=(8,2))

axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)

axes[1].plot(y,x)

plt.tight_layout()

# %%
fig.savefig('my_picture.png',dpi=200)

# %%
fig = plt.figure()

ax =fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')

ax.plot(x,x**3,label='X Cubed')

ax.legend(loc=0)

# %% [markdown]
# ## Part3

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

#ax.plot(x,y,color='orange')
#ax.plot(x,y,color='#FF8C00',linewidth=5) #RGB Color 
#ax.plot(x,y,color='#FF8C00',linewidth=5,alpha=0.1) #Transparency
#ax.plot(x,y,color='#FF8C00',linewidth=5,linestyle='-.') #Line style
ax.plot(x,y,color='#FF8C00',lw=3,ls='-.',marker='o',markersize=10,
       markerfacecolor='green',markeredgewidth=3,markeredgecolor='red') #marker

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color='#FF8C00',lw=2,ls='--')
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)
